# %%
#Import libraries and load dataset
import  tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets,layers,models
import matplotlib.pyplot as plt
import numpy as np

(x_train,y_train),(x_test,y_test)=datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
#Preprocess the data
x_train=x_train/255.0
x_test=x_test/255.0

# %%
x_train=np.expand_dims(x_train,-1)
x_test=np.expand_dims(x_test,-1)

# %%
y_train=keras.utils.to_categorical(y_train,10)
y_test=keras.utils.to_categorical(y_test,10)

# %%
#Build the CNN model
model=keras.Sequential([
    keras.Input(shape=(28,28,1)),
    layers.Conv2D(32,kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Flatten(),
    layers.Dropout(0.5),
    layers.Dense(10,activation='softmax')

])

# %%
model.compile(loss="categorical_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
#Train the model
model.fit(x_train,y_train,epochs=10,batch_size=128,validation_split=0.1)
# Out:
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 45s 101ms/step - accuracy: 0.8874 - loss: 0.3695 - val_accuracy: 0.9772 - val_loss: 0.0867
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 41s 98ms/step - accuracy: 0.9653 - loss: 0.1141 - val_accuracy: 0.9837 - val_loss: 0.0555
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 99ms/step - accuracy: 0.9735 - loss: 0.0857 - val_accuracy: 0.9857 - val_loss: 0.0501
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 100ms/step - accuracy: 0.9776 - loss: 0.0726 - val_accuracy: 0.9893 - val_loss: 0.0396
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 81s 97ms/step - accuracy: 0.9801 - loss: 0.0640 - val_accuracy: 0.9895 - val_loss: 0.0404
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 41s 98ms/step - accuracy: 0.9820 - loss: 0.0577 - val_accuracy: 0.9903 - val_loss: 0.0369
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 41s 97ms/step - accuracy: 0.9835 - loss: 0.0525 - val_accuracy: 0.9903 - val_loss: 0.0370
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 41s 97ms/step - accuracy: 0.9844 - loss: 0.0495 - val_accuracy: 0.9905 - val_loss: 0.0343
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 41s 97ms/step - accuracy: 0.9845 - loss: 0.0464 - val_accuracy: 0.9897 - val_loss: 0.0342
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - accuracy: 0.9861 - loss: 0.0443 - val_accuracy: 0.9918 - val_loss: 0.0292

# %%
#Evaluate the model
test_loss,test_acc=model.evaluate(x_test,y_test)
print(test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9906 - loss: 0.0273
# 0.9905999898910522

# %%
#Test with custom images
import cv2
image=cv2.imread('7.png',cv2.IMREAD_GRAYSCALE)
image=cv2.resize(image,(28,28))

# %%
image=image/255.0

# %%
image=np.expand_dims(image,axis=(0,-1))

# %%
prediction=model.predict(image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
print("predicted digit",np.argmax(prediction))
# Out:
# predicted digit 7

# %%
image=cv2.imread('8.png',cv2.IMREAD_GRAYSCALE)
image=cv2.resize(image,(28,28))
image=image/255.0
image=np.expand_dims(image,axis=(0,-1))
prediction=model.predict(image)
print("predicted digit",np.argmax(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# predicted digit 8

# %%
image=cv2.imread('1.png',cv2.IMREAD_GRAYSCALE)
image=cv2.resize(image,(28,28))
image=image/255.0
image=np.expand_dims(image,axis=(0,-1))
prediction=model.predict(image)
print("predicted digit",np.argmax(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predicted digit 1

# %%
image=cv2.imread('6.jpg',cv2.IMREAD_GRAYSCALE)
image=cv2.resize(image,(28,28))
image=image/255.0
image=np.expand_dims(image,axis=(0,-1))
prediction=model.predict(image)
print("predicted digit",np.argmax(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predicted digit 6

# %%
image=cv2.imread('2.jpg',cv2.IMREAD_GRAYSCALE)
image=cv2.resize(image,(28,28))
image=image/255.0
image=np.expand_dims(image,axis=(0,-1))
prediction=model.predict(image)
print("predicted digit",np.argmax(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predicted digit 2
